# %%
from selenium import webdriver
import chromedriver_binary
import time
import pandas as pd

driver = webdriver.Chrome()

# %%
driver.get('https://www.landofbasketball.com/yearbyyear/2019_2020_standings.htm')

# %%
teams = []
percentages = []
standings = []
seasons = []
for i in range(40):
    
    elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/main/div[5]/div[2]/table')
    w_n = elem.find_elements_by_class_name('a-top')

    elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/main/div[5]/div[3]/table')
    e_n = elem.find_elements_by_class_name('a-top')
    
    whole_n = w_n + e_n
    
    for j in range(len(w_n)):
        elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/main/div[5]/div[2]/table/tbody/tr[{}]/td[2]'.format(j+2))
        team = elem.text
        teams.append(team)
    for j in range(len(e_n)):
        elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/main/div[5]/div[3]/table/tbody/tr[{}]/td[2]'.format(j+2))
        team = elem.text
        teams.append(team)

    for j in range(len(w_n)):
        elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/main/div[5]/div[2]/table/tbody/tr[{}]/td[5]'.format(j+2))
        percentage = float(elem.text)
        percentages.append(percentage)
    for j in range(len(e_n)):
        elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/main/div[5]/div[3]/table/tbody/tr[{}]/td[5]'.format(j+2))
        percentage = float(elem.text)
        percentages.append(percentage)

    for j in range(len(w_n)):
        standing = int(j+1)
        standings.append(standing)
    for j in range(len(e_n)):
        standing = int(j+1)
        standings.append(standing)
        
    for j in range(len(whole_n)):
        season = 2020 - i
        seasons.append(season)
        
    to_previous = driver.find_element_by_xpath('/html/body/div[2]/div[2]/main/div[2]/div[1]/div[3]/div[1]')
    to_previous.click()
    
    time.sleep(5)
# Out:
# /var/folders/9g/_t0rc8jx1x39gdxhtwx6q1vw0000gn/T/ipykernel_23991/1783501828.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/main/div[5]/div[2]/table')
# /var/folders/9g/_t0rc8jx1x39gdxhtwx6q1vw0000gn/T/ipykernel_23991/1783501828.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/main/div[5]/div[3]/table')
# /var/folders/9g/_t0rc8jx1x39gdxhtwx6q1vw0000gn/T/ipykernel_23991/1783501828.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_xpath('/html/body/div[2]/div[2]/main/div[5]/div[2]/table/tbody/tr[{}]/td[2]'.format(j+2))
# ...

# %%
seasons
# Out:
# [2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2019,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
#  2017,
# ...

# %%
team_df = pd.DataFrame(teams, columns=['team'])
standing_df = pd.DataFrame(standings, columns=['standing'])
percentage_df = pd.DataFrame(percentages, columns=['percentage'])
season_df = pd.DataFrame(seasons, columns=['season'])

# %%
previous_records_df = pd.concat([team_df, standing_df, percentage_df, season_df], axis=1)
previous_records_df
# Out:
#                        team  standing  percentage  season
# 0        Los Angeles Lakers         1       0.732    2020
# 1      Los Angeles Clippers         2       0.681    2020
# 2            Denver Nuggets         3       0.630    2020
# 3           Houston Rockets         4       0.611    2020
# 4     Oklahoma City Thunder         5       0.611    2020
# ...                     ...       ...         ...     ...
# 1107     Washington Bullets         7       0.476    1981
# 1108          Atlanta Hawks         8       0.378    1981
# 1109    Cleveland Cavaliers         9       0.341    1981
# 1110        New Jersey Nets        10       0.293    1981
# 1111        Detroit Pistons        11       0.256    1981
#
# [1112 rows x 4 columns]

# %%
previous_records_df.to_csv('previous_percentage_and_standing')
